# %%
import requests
import numpy as np
import pandas as pd
import json
import matplotlib as plt
import gmaps

# Google developer API key
from data_exploration import g_key

# Access maps with unique API key
gmaps.configure(api_key=g_key)

#https://data.cityofnewyork.us/Public-Safety/NYPD-Shooting-Incident-Data-Historic-/833y-fsy8
mapurl = "https://data.cityofnewyork.us/resource/833y-fsy8.json" 
    
crime_map_response = requests.get(mapurl).json()
crime_map_response
# Out:
# [{'incident_key': '156430715',
#   'occur_date': '2016-09-02T00:00:00.000',
#   'occur_time': '20:36:00',
#   'boro': 'BRONX',
#   'precinct': '44',
#   'jurisdiction_code': '0',
#   'statistical_murder_flag': False,
#   'vic_age_group': '25-44',
#   'vic_sex': 'F',
#   'vic_race': 'BLACK',
#   'x_coord_cd': '1007885',
#   'y_coord_cd': '246406',
#   'latitude': '40.842979335000045',
#   'longitude': '-73.91457972899997',
#   'geocoded_column': {'type': 'Point',
#    'coordinates': [-73.91457972899997, 40.842979335000045]},
#   ':@computed_region_efsh_h5xi': '10930',
#   ':@computed_region_f5dn_yrer': '50',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '29',
#   ':@computed_region_sbqj_enih': '27'},
#  {'incident_key': '145001700',
#   'occur_date': '2015-08-02T00:00:00.000',
#   'occur_time': '1:30:00',
#   'boro': 'BRONX',
#   'precinct': '43',
#   'jurisdiction_code': '0',
#   'statistical_murder_flag': False,
#   'vic_age_group': '<18',
# ...

# %%
#incidents = []
borough = []
#coordinates = {}

for incident in crime_map_response:
    #incidents.append(crime_map_reponse[0]['incident key'])
    borough.append(crime_map_response[0]['boro'])
    #coordinates.append(crime_map_response[0]['coordinates'])

#access maps with unique API key
#gmaps.configure(api_key = g_key)

#create coordinates
#records = weather_df[["Latitude", "Longitude"]].to_records(index=False)
#coordinates = list(records)
#weights = weather_df['Humidity']
#customize map
#figure_layout = {'width': '500px', 'margin': '0 auto 0 auto'}
#fig = gmaps.figure(layout=figure_layout)
#heat_layer = gmaps.heatmap_layer(crime_map_response[0]['coordinates'], weights = weights)

#assign marker layer
#fig.add_layer(heat_layer)
#fig
print(borough)
